# %% [markdown]
# Florentino Benedictus - 5025201222
# Tugas ETS KIJ D - Implementasi DES Algorithm
#
# Ref:
# - https://www.geeksforgeeks.org/data-encryption-standard-des-set-1/
# - https://www.geeksforgeeks.org/what-is-p-box-in-cryptography/
# - https://en.wikipedia.org/wiki/DES_supplementary_material
# - https://www.youtube.com/watch?v=j53iXhTSi_s
# - https://www.youtube.com/watch?v=SaZGjQBItBc

# %%
# define macros
initial_permutation = [58, 50, 42, 34, 26, 18, 10, 2,
                60, 52, 44, 36, 28, 20, 12, 4,
                62, 54, 46, 38, 30, 22, 14, 6,
                64, 56, 48, 40, 32, 24, 16, 8,
                57, 49, 41, 33, 25, 17, 9, 1,
                59, 51, 43, 35, 27, 19, 11, 3,
                61, 53, 45, 37, 29, 21, 13, 5,
                63, 55, 47, 39, 31, 23, 15, 7]

final_permutation = [40, 8, 48, 16, 56, 24, 64, 32,
              39, 7, 47, 15, 55, 23, 63, 31,
              38, 6, 46, 14, 54, 22, 62, 30,
              37, 5, 45, 13, 53, 21, 61, 29,
              36, 4, 44, 12, 52, 20, 60, 28,
              35, 3, 43, 11, 51, 19, 59, 27,
              34, 2, 42, 10, 50, 18, 58, 26,
              33, 1, 41, 9, 49, 17, 57, 25]

s_box = [[[14, 4, 13, 1, 2, 15, 11, 8, 3, 10, 6, 12, 5, 9, 0, 7],
         [0, 15, 7, 4, 14, 2, 13, 1, 10, 6, 12, 11, 9, 5, 3, 8],
         [4, 1, 14, 8, 13, 6, 2, 11, 15, 12, 9, 7, 3, 10, 5, 0],
         [15, 12, 8, 2, 4, 9, 1, 7, 5, 11, 3, 14, 10, 0, 6, 13]],

        [[15, 1, 8, 14, 6, 11, 3, 4, 9, 7, 2, 13, 12, 0, 5, 10],
         [3, 13, 4, 7, 15, 2, 8, 14, 12, 0, 1, 10, 6, 9, 11, 5],
         [0, 14, 7, 11, 10, 4, 13, 1, 5, 8, 12, 6, 9, 3, 2, 15],
         [13, 8, 10, 1, 3, 15, 4, 2, 11, 6, 7, 12, 0, 5, 14, 9]],

        [[10, 0, 9, 14, 6, 3, 15, 5, 1, 13, 12, 7, 11, 4, 2, 8],
         [13, 7, 0, 9, 3, 4, 6, 10, 2, 8, 5, 14, 12, 11, 15, 1],
         [13, 6, 4, 9, 8, 15, 3, 0, 11, 1, 2, 12, 5, 10, 14, 7],
         [1, 10, 13, 0, 6, 9, 8, 7, 4, 15, 14, 3, 11, 5, 2, 12]],

        [[7, 13, 14, 3, 0, 6, 9, 10, 1, 2, 8, 5, 11, 12, 4, 15],
         [13, 8, 11, 5, 6, 15, 0, 3, 4, 7, 2, 12, 1, 10, 14, 9],
         [10, 6, 9, 0, 12, 11, 7, 13, 15, 1, 3, 14, 5, 2, 8, 4],
         [3, 15, 0, 6, 10, 1, 13, 8, 9, 4, 5, 11, 12, 7, 2, 14]],

        [[2, 12, 4, 1, 7, 10, 11, 6, 8, 5, 3, 15, 13, 0, 14, 9],
         [14, 11, 2, 12, 4, 7, 13, 1, 5, 0, 15, 10, 3, 9, 8, 6],
         [4, 2, 1, 11, 10, 13, 7, 8, 15, 9, 12, 5, 6, 3, 0, 14],
         [11, 8, 12, 7, 1, 14, 2, 13, 6, 15, 0, 9, 10, 4, 5, 3]],

        [[12, 1, 10, 15, 9, 2, 6, 8, 0, 13, 3, 4, 14, 7, 5, 11],
         [10, 15, 4, 2, 7, 12, 9, 5, 6, 1, 13, 14, 0, 11, 3, 8],
         [9, 14, 15, 5, 2, 8, 12, 3, 7, 0, 4, 10, 1, 13, 11, 6],
         [4, 3, 2, 12, 9, 5, 15, 10, 11, 14, 1, 7, 6, 0, 8, 13]],

        [[4, 11, 2, 14, 15, 0, 8, 13, 3, 12, 9, 7, 5, 10, 6, 1],
         [13, 0, 11, 7, 4, 9, 1, 10, 14, 3, 5, 12, 2, 15, 8, 6],
         [1, 4, 11, 13, 12, 3, 7, 14, 10, 15, 6, 8, 0, 5, 9, 2],
         [6, 11, 13, 8, 1, 4, 10, 7, 9, 5, 0, 15, 14, 2, 3, 12]],

        [[13, 2, 8, 4, 6, 15, 11, 1, 10, 9, 3, 14, 5, 0, 12, 7],
         [1, 15, 13, 8, 10, 3, 7, 4, 12, 5, 6, 11, 0, 14, 9, 2],
         [7, 11, 4, 1, 9, 12, 14, 2, 0, 6, 10, 13, 15, 3, 5, 8],
         [2, 1, 14, 7, 4, 10, 8, 13, 15, 12, 9, 0, 3, 5, 6, 11]]]

expansion_p_box = [32, 1, 2, 3, 4, 5, 4, 5,
         6, 7, 8, 9, 8, 9, 10, 11,
         12, 13, 12, 13, 14, 15, 16, 17,
         16, 17, 18, 19, 20, 21, 20, 21,
         22, 23, 24, 25, 24, 25, 26, 27,
         28, 29, 28, 29, 30, 31, 32, 1]

straight_p_box = [16, 7, 20, 21, 29, 12, 28, 17,
              1, 15, 23, 26, 5, 18, 31, 10,
              2, 8, 24, 14, 32, 27, 3, 9,
              19, 13, 30, 6, 22, 11, 4, 25]

permuted_choice_1 = [
    57, 49, 41, 33, 25, 17, 9, 1,
    58, 50, 42, 34, 26, 18, 10, 2,
    59, 51, 43, 35, 27, 19, 11, 3,
    60, 52, 44, 36, 63, 55, 47, 39,
    31, 23, 15, 7, 62, 54, 46, 38,
    30, 22, 14, 6, 61, 53, 45, 37,
    29, 21, 13, 5, 28, 20, 12, 4
]

permuted_choice_2 = [
    14, 17, 11, 24, 1, 5, 3, 28,
    15, 6, 21, 10, 23, 19, 12, 4,
    26, 8, 16, 7, 27, 20, 13, 2,
    41, 52, 31, 37, 47, 55, 30, 40,
    51, 45, 33, 48, 44, 49, 39, 56,
    34, 53, 46, 42, 50, 36, 29, 32
]

shift_amount = [1, 1, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 1]

# %%
def generate_round_keys(key):
    round_keys = []

    # Permuted Choice - 1 (PC-1). 64bit->56bit
    key_permuted = [key[pc - 1] for pc in permuted_choice_1]


    # Split Left Key (Lk) & Right Key (Rk). 56bit->2x28bit
    left_half = key_permuted[:28]
    right_half = key_permuted[28:]

    for i in range(16):
        # Left Circular Shift (LCS). 28bit->28bit
        left_half = left_half[shift_amount[i]:] + left_half[:shift_amount[i]]
        right_half = right_half[shift_amount[i]:] + right_half[:shift_amount[i]]


        # Combine Lk & Rk, perform Permuted Choice - 2 (PC-2) to generate round sub-key. 56bit->48bit
        combined_key = left_half + right_half
        round_key = [combined_key[pc2 - 1] for pc2 in permuted_choice_2]

        round_keys.append("".join(round_key))

        # left_half & right_half kept for use in next iter...

    return round_keys

def initial_permute(data):
    res = ""
    for i in range(64):
        res += data[initial_permutation[i] - 1]
    return res

def expansion_permutation(data):
    res = ""
    for i in range(48):
        res += data[expansion_p_box[i] - 1]
    return res

def s_box_substitution(data):
    res = ""

    # Split and iterate S1-S8. 48bit->8x6bit->8x4bit->32bit
    for i in range(8):
        # Get value of Sn (6bit)
        block = data[i * 6:(i + 1) * 6]

        # 1st & 6th bit as row index
        row = int(block[0] + block[5], 2)

        # 2nd - 5th bit as column index
        col = int(block[1:5], 2)

        # Map indexes into S-Box
        val = s_box[i][row][col]

        # Append resulting S-box value as 4bit
        res += format(val, '04b')
    return res

def straight_permutation(data):
    res = ""
    for i in range(32):
        res += data[straight_p_box[i] - 1]
    return res

def des_round(data, key):
    # Perform Expansion Permutation (E). 32bit->48bit
    expanded_data = expansion_permutation(data)

    # XOR, expanded_data ^ PC-2. 48bit->48bit
    xor_result = "".join([str(int(b1) ^ int(b2)) for b1, b2 in zip(expanded_data, key)])

    # Substitution (S-Box). 48bit->32bit
    s_box_result = s_box_substitution(xor_result)

    # Straight Permutation (P). 32bit->32bit
    round_output = straight_permutation(s_box_result)
    return round_output

def final_permute(data):
    res = ""
    for i in range(64):
        res += data[final_permutation[i] - 1]
    return res

def des_encrypt(data, round_keys):
    # Initial Permutation (IP). 64bit->64bit
    data = initial_permute(data)

    # Split Left Data (L) & Right Data (R). 64bit->2x32bit
    left_half = data[:32]
    right_half = data[32:]

    # Begin 16 rounds
    for i in range(16):
        # Swap Old-R -> New-L
        new_left_half = right_half

        # Perform Round-n Function using subkey-n
        round_output = des_round(right_half, round_keys[i])

        # Final XOR, Permutation Result ^ Old-L. 32bit->32bit
        new_right_half = "".join([str(int(b1) ^ int(b2)) for b1, b2 in zip(left_half, round_output)])

        # Update L & R variables for next iter
        left_half, right_half = new_left_half, new_right_half

    # Final 32-bit swap (after round-16). 2x32bit->2x32bit
    left_half, right_half = right_half, left_half

    # Combine left & right halves. 2x32bit->64bit
    combined_data = left_half + right_half

    # Final Permutation (FP)/ Inverse Initial Permutation (IP^-1). 64bit->64bit
    ciphertext = final_permute(combined_data)
    return ciphertext

def des_decrypt(data, round_keys):
    # Initial Permutation (IP). 64bit->64bit
    data = initial_permute(data)

    # Split Left Data (L) & Right Data (R). 64bit->2x32bit
    left_half = data[:32]
    right_half = data[32:]

    # Begin 16 rounds in reverse order
    for i in range(15, -1, -1):
        # Swap Old-R -> New-L
        new_left_half = right_half

        # Perform Round-n Function using subkey-n
        round_output = des_round(right_half, round_keys[i])

        # Final XOR, Permutation Result ^ Old-L. 32bit->32bit
        new_right_half = "".join([str(int(b1) ^ int(b2)) for b1, b2 in zip(left_half, round_output)])

        # Update L & R variables for next iter
        left_half, right_half = new_left_half, new_right_half

    # Final 32-bit swap (after round-16). 2x32bit->2x32bit
    left_half, right_half = right_half, left_half

    # Combine left & right halves. 2x32bit->64bit
    combined_data = left_half + right_half

    # Final Permutation (FP)/ Inverse Initial Permutation (IP^-1). 64bit->64bit
    ciphertext = final_permute(combined_data)
    return ciphertext

def des_algorithm(key_hex = "e3b98d45a5b38a7f", plaintext_hex = "1f05d3c2872a59b6", ciphertext_hex = "f48e3583f49c76f6"):

    # Convert key & plaintext from hex/base-16 to binary
    key_binary = bin(int(key_hex, 16))[2:].zfill(64)
    plaintext_binary = bin(int(plaintext_hex, 16))[2:].zfill(64)

    # Generate 16 round sub-keys
    round_keys = generate_round_keys(key_binary)

    # print(key_binary)
    # print(round_keys)

    # print(plaintext_binary)

    encrypted_ciphertext_binary = des_encrypt(plaintext_binary, round_keys)

    # OPTION 1: Use macro ciphertext
    ciphertext_binary = bin(int(ciphertext_hex, 16))[2:].zfill(64)
    decrypted_plaintext_binary = des_decrypt(ciphertext_binary, round_keys)

    # OPTION 2: Use encrypted ciphertext
    # decrypted_plaintext_binary = des_decrypt(encrypted_ciphertext_binary, round_keys)

    # Convert binary back to hex
    encrypted_ciphertext = hex(int(encrypted_ciphertext_binary, 2))[2:].zfill(16)
    decrypted_plaintext = hex(int(decrypted_plaintext_binary, 2))[2:].zfill(16)

    # print("Original data:", plaintext_hex)
    # print("Encrypted data:", encrypted_ciphertext)
    # print("Decrypted data:", decrypted_plaintext)

    return plaintext_hex, encrypted_ciphertext, decrypted_plaintext

# %%
if __name__ == "__main__":
  # OPTION 1: 64bit hex input

  # Input: 64bit key + 64bit plaintext/ciphertext
  key_hex = "133457799bbcdff1"
  plaintext_hex = "0123456789abcdef"
  ciphertext_hex = "85e813540f0ab405"

  # DES 64-bit algorithm. 64bit plaintext->64bit ciphertext or 64bit ciphertext->64bit plaintext
  plaintext_hex, encrypted_ciphertext, decrypted_plaintext = des_algorithm(key_hex, plaintext_hex, ciphertext_hex)

  print("Original data:", plaintext_hex)
  print("Encrypted data:", encrypted_ciphertext)
  print("Decrypted data:", decrypted_plaintext)



  print("-----------------------------------------------------------------------------------------------------------------------------------")

  # OPTION 2: arbitrary input plaintext string

  # Input: 64bit key + any length plaintext string/ciphertext hex string
  key_hex = "8b52aec7d4b5229f"
  plaintext = "lab kbj jam 10"
  ciphertext_hex = "72d048b5e65c2382fe731fa5078e4585"

  # Add padding to make string bit size multiple of 64bit
  plaintext += '\x00' * (((64 - (len(plaintext) * 8) % 64) + 7) // 8)

  # Convert whole string to hex
  plaintext_hex = plaintext.encode().hex()

  # print(plaintext_hex)
  # print(ciphertext_hex)

  # Take 64bit per iter (DES is block cipher)
  block_size = 16 # 16 hex characters = 16x4bit = 64bit
  plaintext_blocks = [plaintext_hex[i:i + block_size] for i in range(0, len(plaintext_hex), block_size)]
  ciphertext_blocks = [ciphertext_hex[i:i + block_size] for i in range(0, len(ciphertext_hex), block_size)]

  resulting_ciphertext = ""
  for i in range(len(plaintext_blocks)):
      # print(f"64-bit block {i + 1} - Plaintext: {plaintext_blocks[i]}")
      plaintext_hex, encrypted_ciphertext, decrypted_plaintext = des_algorithm(key_hex = key_hex, plaintext_hex = plaintext_blocks[i])
      resulting_ciphertext += encrypted_ciphertext
  print("Encrypted blocks:", resulting_ciphertext)

  resulting_plaintext = ""
  for i in range(len(ciphertext_blocks)):
      # print(f"64-bit block {i + 1} - Ciphertext: {ciphertext_blocks[i]}")
      plaintext_hex, encrypted_ciphertext, decrypted_plaintext = des_algorithm(key_hex, ciphertext_hex = ciphertext_blocks[i])
      resulting_plaintext += decrypted_plaintext
  print("Decrypted blocks:", bytes.fromhex(resulting_plaintext).decode())
# Out:
# Original data: 0123456789abcdef
# Encrypted data: 85e813540f0ab405
# Decrypted data: 0123456789abcdef
# -----------------------------------------------------------------------------------------------------------------------------------
# Encrypted blocks: 72d048b5e65c2382fe731fa5078e4585
# Decrypted blocks: lab kbj jam 10
